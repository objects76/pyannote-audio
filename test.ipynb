# %%
from vad_test import test_vad

anno_vad = test_vad()
anno_vad
# Out:
# [TRY] Loading model from pyan30 ...
# [OK] Model loaded: PyanNet
#
# [RUN] Processing 촉법소년.m4a ...
#
# [RESULT] VAD output:
#      2.66s -    2.92s  [SPEECH]
#      4.15s -    7.52s  [SPEECH]
#      7.83s -   14.59s  [SPEECH]
#     14.73s -   19.79s  [SPEECH]
#     20.67s -   26.93s  [SPEECH]
#     27.08s -   29.12s  [SPEECH]
#     29.88s -   48.34s  [SPEECH]
#     49.20s -   54.32s  [SPEECH]
#     55.06s -   58.52s  [SPEECH]
#     58.92s -   60.65s  [SPEECH]
#     60.93s -   67.33s  [SPEECH]
#     68.97s -   74.80s  [SPEECH]
#     75.19s -   79.65s  [SPEECH]
#     80.36s -   85.69s  [SPEECH]
#     86.82s -   93.33s  [SPEECH]
#     93.81s -   94.94s  [SPEECH]
#     95.34s -   99.44s  [SPEECH]
#     99.81s -  107.51s  [SPEECH]
#    107.93s -  113.55s  [SPEECH]
#    114.34s -  118.07s  [SPEECH]
#    118.21s -  120.47s  [SPEECH]
#    121.23s -  127.23s  [SPEECH]
#    127.74s -  141.41s  [SPEECH]
#    142.08s -  148.02s  [SPEECH]
#    148.83s -  151.60s  [SPEECH]
# ...
